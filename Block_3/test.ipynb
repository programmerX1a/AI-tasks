# %%
from sklearn.preprocessing import OneHotEncoder,LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df_x=pd.read_csv("train.csv")
df_y=pd.read_csv("test.csv")
important_attributes=df_y.columns[23:].drop(["performance_score"])
important_df_y=pd.get_dummies(df_y[important_attributes], drop_first=True)
important_df_x=pd.get_dummies(df_x[important_attributes] ,drop_first=True)
scaler=StandardScaler()
y=df_x["player_rating"]
pca=PCA(n_components=0.95)
scaled_x=scaler.fit_transform(important_df_x)
pca_scores=pca.fit_transform(scaled_x)
sns.scatterplot(x=pca_scores[:,0],y=pca_scores[:,1],hue=df_x["position"])
# Out:
# <Axes: >

# %%
sns.scatterplot(x=pca_scores[:,2],y=pca_scores[:,3],hue=df_x["position"])
# Out:
# <Axes: >

# %%
sns.scatterplot(x=pca_scores[:,4],y=pca_scores[:,5],hue=df_x["position"])
# Out:
# <Axes: >

# %%
sns.scatterplot(x=pca_scores[:6],y=pca_scores[:7],hue=df_x["position"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sns.scatterplot(x=pca_scores[:6],y=pca_scores[:7],hue=df_x["position"])
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/seaborn/relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)    612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     622     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# ...

# %%
sns.scatterplot(x=pca_scores[:,8],y=pca_scores[:,9],hue=df_x["position"])
# Out:
# <Axes: >

# %%
sns.scatterplot(x=df_x["goals"],y=df_x["player_rating"],hue=df_x["position"])
# Out:
# <Axes: xlabel='goals', ylabel='player_rating'>
